# %%
import json 
import pandas as pd

# %%
filename = "bart_stop_stats.json"
pd.read_json("http://raw.githubusercontent.com/streamlit/"
        "example-data/master/hello/v1/%s" % filename)
# Out:
#                                         name code  \
# 0                           Lafayette (LAFY)   LF
# 1        12th St. Oakland City Center (12TH)   12
# 2                    16th St. Mission (16TH)   16
# 3                    19th St. Oakland (19TH)   19
# 4                    24th St. Mission (24TH)   24
# 5                               Ashby (ASHB)   AS
# 6                         Balboa Park (BALB)   BP
# 7                            Bay Fair (BAYF)   BF
# 8                       Castro Valley (CAST)   CV
# 9               Civic Center/UN Plaza (CIVC)   CC
# 10                              Colma (COLM)   CM
# 11           Coliseum/Oakland Airport (COLS)   CL
# 12                            Concord (CONC)   CN
# 13                          Daly City (DALY)   DC
# 14                  Downtown Berkeley (DBRK)   BK
# 15               El Cerrito del Norte (DELN)   EN
# 16                  Dublin/Pleasanton (DUBL)   ED
# 17                        Embarcadero (EMBR)   EM
# ...

# %%
filename = "bart_path_stats.json"
pd.read_json("http://raw.githubusercontent.com/streamlit/"
        "example-data/master/hello/v1/%s" % filename)

# %%
filename = "bart_path_stats.json"
pd.read_json("http://raw.githubusercontent.com/streamlit/"
        "example-data/master/hello/v1/%s" % filename)
# Out:
#     inbound  outbound         lon        lat        lon2       lat2
# 0     72633     74735 -122.269029  37.807870 -122.271604  37.803664
# 1     65042     67529 -122.271604  37.803664 -122.294582  37.804675
# 2         0     23821 -122.265609  37.797484 -122.271604  37.803664
# 3     62964     58788 -122.419694  37.765062 -122.413756  37.779528
# 4     55134     51019 -122.418466  37.752254 -122.419694  37.765062
# 5     67975     70088 -122.267227  37.828415 -122.269029  37.807870
# 6     45831     42007 -122.434092  37.732921 -122.418466  37.752254
# 7      4158      4000 -122.353165  37.936887 -122.317269  37.925655
# 8     12012     12338 -122.317269  37.925655 -122.299272  37.903059
# 9     16343     16856 -122.299272  37.903059 -122.283451  37.874040
# 10    20199     20909 -122.283451  37.874040 -122.268045  37.869867
# 11    26650     28041 -122.268045  37.869867 -122.269780  37.853024
# 12    30485     31757 -122.269780  37.853024 -122.267227  37.828415
# ...
